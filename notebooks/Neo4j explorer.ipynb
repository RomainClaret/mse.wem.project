# %%
import pandas as pd
from py2neo import Graph

# %%
graph = Graph('bolt://127.0.0.1:7687/db/data')

# %%
def to_df(result):
    return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %% [markdown]
# ## Data exploration

# %%
to_df(graph.run("MATCH (n) RETURN distinct labels(n), count(*)"))
# Out:
#        labels(n)  count(*)
# 0  [Publication]     50000
# 1     [Category]       160
# 2       [Author]     94540

# %%
to_df(graph.run("MATCH (p:Publication) RETURN p.id AS id, p.title AS title"))
# Out:
#                                       id  \
# 0      http://arxiv.org/abs/1906.02739v1
# 1      http://arxiv.org/abs/1906.02738v1
# 2      http://arxiv.org/abs/1906.02736v1
# 3      http://arxiv.org/abs/1906.02735v1
# 4      http://arxiv.org/abs/1906.02611v1
# 5      http://arxiv.org/abs/1906.02732v1
# 6      http://arxiv.org/abs/1906.02729v1
# 7      http://arxiv.org/abs/1906.02728v1
# 8      http://arxiv.org/abs/1906.02719v1
# 9      http://arxiv.org/abs/1906.02717v1
# 10     http://arxiv.org/abs/1905.13210v2
# 11     http://arxiv.org/abs/1906.02715v1
# 12     http://arxiv.org/abs/1905.02706v2
# 13     http://arxiv.org/abs/1703.10326v4
# 14     http://arxiv.org/abs/1906.02707v1
# 15     http://arxiv.org/abs/1906.01738v2
# 16     http://arxiv.org/abs/1906.02702v1
# 17     http://arxiv.org/abs/1906.02698v1
# 18     http://arxiv.org/abs/1810.04009v4
# 19     http://arxiv.org/abs/1906.02694v1
# 20      http://arxiv.org/abs/1405.3316v2
# 21     http://arxiv.org/abs/1906.02691v1
# 22     http://arxiv.org/abs/1906.02685v1
# 23     http://arxiv.org/abs/1901.07213v3
# 24     http://arxiv.org/abs/1906.02680v1
# 25     http://arxiv.org/abs/1905.11545v3
# 26     http://arxiv.org/abs/1906.02667v1
# 27     http://arxiv.org/abs/1906.01228v2
# 28     http://arxiv.org/abs/1906.02664v1
# 29     http://arxiv.org/abs/1906.02660v1
# ...                                  ...
# 49970   http://arxiv.org/abs/0906.0298v1
# 49971   http://arxiv.org/abs/0906.0281v1
# 49972   http://arxiv.org/abs/0906.0268v1
# 49973   http://arxiv.org/abs/0906.0252v1
# 49974   http://arxiv.org/abs/0906.0247v1
# 49975   http://arxiv.org/abs/0904.0721v2
# 49976   http://arxiv.org/abs/0906.0237v1
# 49977   http://arxiv.org/abs/0905.4627v2
# 49978   http://arxiv.org/abs/0906.0205v1
# 49979   http://arxiv.org/abs/0906.0202v1
# 49980   http://arxiv.org/abs/0906.0151v1
# 49981   http://arxiv.org/abs/0810.0745v3
# 49982   http://arxiv.org/abs/0906.0052v1
# 49983   http://arxiv.org/abs/0906.0049v1
# 49984   http://arxiv.org/abs/0906.0037v1
# 49985   http://arxiv.org/abs/0901.2401v2
# 49986   http://arxiv.org/abs/0905.4926v1
# 49987   http://arxiv.org/abs/0905.4918v1
# 49988   http://arxiv.org/abs/0905.4909v1
# 49989   http://arxiv.org/abs/0905.4906v1
# 49990   http://arxiv.org/abs/0905.4905v1
# 49991   http://arxiv.org/abs/0905.4902v1
# 49992   http://arxiv.org/abs/0905.4887v1
# 49993   http://arxiv.org/abs/0905.4612v2
# 49994   http://arxiv.org/abs/0905.4864v1
# 49995   http://arxiv.org/abs/0905.4863v1
# 49996   http://arxiv.org/abs/0905.4860v1
# 49997   http://arxiv.org/abs/0905.4850v1
# 49998   http://arxiv.org/abs/0808.0075v4
# 49999   http://arxiv.org/abs/0903.0802v2
#
#                                                    title
# 0                                             Mesh R-CNN
# 1      Conversing by Reading: Contentful Neural Conve...
# 2      DeepMDP: Learning Continuous Latent Space Mode...
# 3      Residual Flows for Invertible Generative Modeling
# 4      Improving Robustness Without Sacrificing Accur...
# 5      A Look at the Effect of Sample Design on Gener...
# 6      3D-RelNet: Joint Object and Relational Network...
# 7      Feature-level and Model-level Audiovisual Fusi...
# 8      Learning Gaussian Graphical Models with Ordere...
# 9          Adaptive Gradient-Based Meta-Learning Methods
# 10     Generalization Bounds of Stochastic Gradient D...
# 11        Visualizing and Measuring the Geometry of BERT
# 12     Learning Unsupervised Multi-View Stereopsis vi...
# 13     Randomness extraction via a quantum generaliza...
# 14     Unsupervised Co-Learning on $mathcal{G}$-Manif...
# 15     A Just and Comprehensive Strategy for Using NL...
# 16     A Non-Asymptotic Analysis of Network Independe...
# 17     Training large-scale ANNs on simulated resisti...
# 18     Deep learning: Extrapolation tool for ab initi...
# 19                Deep Semi-Supervised Anomaly Detection
# 20     Optimal Exploration-Exploitation in a Multi-Ar...
# 21           An Introduction to Variational Autoencoders
# 22         Stochastic Bandits with Context Distributions
# 23     A Fully Convolutional Network for Rectal Cance...
# 24     A method for the classification of chimera sta...
# 25                          Learning Bregman Divergences
# 26     Failures detection at directional drilling usi...
# 27     A deterministic algorithm for counting colorin...
# 28     Machine Learning and Visualization in Clinical...
# 29     How a Single Paper Affects the Impact Factor: ...
# ...                                                  ...
# 49970  Delay-Optimal Power and Precoder Adaptation fo...
# 49971  Microcontroller based distributed and networke...
# 49972  MORA: an Energy-Aware Slack Reclamation Scheme...
# 49973  Progressive Processing of Continuous Range Que...
# 49974  Coded Modulation with Mismatched CSIT over Blo...
# 49975        Optimal Tableau Decision Procedures for PDL
# 49976  Multi-Linear cryptanalysis in Power Analysis A...
# 49977  CoPhIR: a Test Collection for Content-Based Im...
# 49978                  A Survey of Tree Convex Sets Test
# 49979  Mitigating the ICA Attack against Rotation Bas...
# 49980  Inventory competition in a multi channel distr...
# 49981  Stackelberg Contention Games in Multiuser Netw...
# 49982  A Minimum Description Length Approach to Multi...
# 49983  Towards Automated Deduction in Blackmail Case ...
# 49984  Asymptotic Capacity and Optimal Precoding in M...
# 49985  MIMO Broadcast Channel Optimization under Gene...
# 49986  On Node Density -- Outage Probability Tradeoff...
# 49987  Divide and Conquer: Partitioning Online Social...
# 49988                  On the Convex Feasibility Problem
# 49989         On Some Manipulations with Fuzzy Processes
# 49990  Aspects Regarding Operations with Fuzzy Processes
# 49991     Flexible frontiers for text division into rows
# 49992     Persistent Cohomology and Circular Coordinates
# 49993  Straight-line instruction sequence completenes...
# 49994  Computer Based Interpretation of the Students'...
# 49995  Derivation of UML Based Performance Models for...
# 49996  Informatics Issues Used in the Production Dash...
# 49997           A Survey on Cross-Site Scripting Attacks
# 49998  Optimal Beamforming for Two-Way Multi-Antenna ...
# 49999  An Epistemic Approach to Coercion-Resistance f...
#
# [50000 rows x 2 columns]

# %% [markdown]
# ## Query relationships

# %%
pub = 'http://arxiv.org/abs/1906.02739v1'

# %%
query = """
MATCH (p1:Publication)-[r]-(n)
WHERE p1.id = {pub}
RETURN p1.title, type(r), n.name
"""

to_df(graph.run(query, pub=pub))
# Out:
#      p1.title               type(r)            n.name
# 0  Mesh R-CNN                 WROTE    Justin Johnson
# 1  Mesh R-CNN                 WROTE    Jitendra Malik
# 2  Mesh R-CNN                 WROTE  Georgia Gkioxari
# 3  Mesh R-CNN  HAS_PRIMARY_CATEGORY             cs.CV
# 4  Mesh R-CNN          HAS_CATEGORY             cs.CV

# %%
query = """
MATCH (p1:Publication)-[]-(rn)-[]-(p2:Publication)
WHERE p1.id = {pub}
RETURN p1.id, p1.title, count(rn) as n_relations, p2.id, p2.title
ORDER BY n_relations DESC
LIMIT 10
"""

to_df(graph.run(query, pub=pub))
# Out:
#                                p1.id    p1.title  n_relations  \
# 0  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            6
# 1  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 2  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 3  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 4  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 5  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 6  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 7  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 8  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
# 9  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN            5
#
#                                p2.id  \
# 0  http://arxiv.org/abs/1903.09977v2
# 1  http://arxiv.org/abs/1904.03239v1
# 2  http://arxiv.org/abs/1811.12373v1
# 3  http://arxiv.org/abs/1901.01971v2
# 4  http://arxiv.org/abs/1809.02882v1
# 5  http://arxiv.org/abs/1904.01201v1
# 6  http://arxiv.org/abs/1812.00940v1
# 7  http://arxiv.org/abs/1905.13214v1
# 8  http://arxiv.org/abs/1702.03920v3
# 9  http://arxiv.org/abs/1812.03982v2
#
#                                             p2.title
# 0  Joint Learning of Discriminative Low-dimension...
# 1  ShapeMask: Learning to Segment Novel Objects b...
# 2  Diverse Image Synthesis from Semantic Layouts ...
# 3  Learning Independent Object Motion from Unlabe...
# 4  Cost-Sensitive Active Learning for Intracrania...
# 5       Habitat: A Platform for Embodied AI Research
# 6            Visual Memory for Robust Path Following
# 7    On Network Design Spaces for Visual Recognition
# 8  Cognitive Mapping and Planning for Visual Navi...
# 9            SlowFast Networks for Video Recognition

# %% [markdown]
# ## Compute similarities

# %%
query = """
MATCH (pub:Publication)-[]-(rel)
WITH {item: id(pub), categories: collect(id(rel))} as pubData
WITH collect(pubData) as data

CALL algo.similarity.jaccard(data, {concurrency:1, similarityCutoff: 0.1, write:false})
YIELD nodes, similarityPairs, write, writeRelationshipType, writeProperty, min, max, mean, stdDev, p25, p50, p75, p90, p95, p99, p999, p100

RETURN nodes, similarityPairs, write, writeRelationshipType, writeProperty, min, max, mean, p95
"""

to_df(graph.run(query, pub=pub))
# Out:
#    nodes  similarityPairs  write writeRelationshipType writeProperty  min  \
# 0  50000        126472142  False               SIMILAR         score  0.1
#
#         max      mean       p95
# 0  1.000007  0.197844  0.333333

# %%
query = """
MATCH (pub:Publication)-[]-(rel), (from:Publication {id: {pub}})
WITH {item: id(pub), categories: collect(id(rel))} as pubData, [id(from)] as sourceIds
WITH collect(pubData) as data, sourceIds

CALL algo.similarity.overlap.stream(data, {sourceIds: sourceIds, concurrency:1, similarityCutoff: 0.1})
YIELD item1, item2, similarity
WITH algo.getNodeById(item1) AS from, algo.getNodeById(item2) AS to, similarity

RETURN from.id, from.title, to.id, to.title, similarity
ORDER BY similarity DESC
LIMIT 100
"""

to_df(graph.run(query, pub=pub))
# Out:
#                               from.id  from.title  \
# 0   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 1   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 2   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 3   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 4   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 5   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 6   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 7   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 8   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 9   http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 10  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 11  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 12  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 13  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 14  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 15  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 16  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 17  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 18  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 19  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 20  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 21  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 22  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 23  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 24  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 25  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 26  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 27  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 28  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 29  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# ..                                ...         ...
# 70  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 71  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 72  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 73  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 74  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 75  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 76  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 77  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 78  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 79  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 80  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 81  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 82  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 83  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 84  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 85  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 86  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 87  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 88  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 89  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 90  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 91  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 92  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 93  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 94  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 95  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 96  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 97  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 98  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 99  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
#
#                                 to.id  \
# 0   http://arxiv.org/abs/1812.01601v3
# 1   http://arxiv.org/abs/1811.12373v1
# 2   http://arxiv.org/abs/1905.13214v1
# 3   http://arxiv.org/abs/1806.03265v2
# 4   http://arxiv.org/abs/1904.03461v1
# 5   http://arxiv.org/abs/1904.03239v1
# 6   http://arxiv.org/abs/1809.02882v1
# 7   http://arxiv.org/abs/1905.07553v2
# 8   http://arxiv.org/abs/1702.03920v3
# 9   http://arxiv.org/abs/1904.01201v1
# 10  http://arxiv.org/abs/1812.00940v1
# 11  http://arxiv.org/abs/1901.01971v2
# 12  http://arxiv.org/abs/1812.03982v2
# 13  http://arxiv.org/abs/1812.11971v3
# 14  http://arxiv.org/abs/1904.04686v1
# 15  http://arxiv.org/abs/1906.02634v1
# 16  http://arxiv.org/abs/1906.01340v1
# 17  http://arxiv.org/abs/1906.01314v1
# 18  http://arxiv.org/abs/1906.01347v1
# 19  http://arxiv.org/abs/1906.01363v1
# 20  http://arxiv.org/abs/1906.01344v1
# 21  http://arxiv.org/abs/1906.01308v1
# 22  http://arxiv.org/abs/1712.09196v3
# 23  http://arxiv.org/abs/1906.00925v2
# 24  http://arxiv.org/abs/1906.02659v1
# 25  http://arxiv.org/abs/1906.01357v1
# 26  http://arxiv.org/abs/1906.02534v1
# 27  http://arxiv.org/abs/1906.01342v1
# 28  http://arxiv.org/abs/1906.02526v1
# 29  http://arxiv.org/abs/1809.00263v4
# ..                                ...
# 70  http://arxiv.org/abs/1906.01885v1
# 71  http://arxiv.org/abs/1904.00818v4
# 72  http://arxiv.org/abs/1905.07481v2
# 73  http://arxiv.org/abs/1906.02495v1
# 74  http://arxiv.org/abs/1906.01223v2
# 75  http://arxiv.org/abs/1906.01857v1
# 76  http://arxiv.org/abs/1904.02307v3
# 77  http://arxiv.org/abs/1906.01851v1
# 78  http://arxiv.org/abs/1906.01828v1
# 79  http://arxiv.org/abs/1906.01821v1
# 80  http://arxiv.org/abs/1906.02295v1
# 81  http://arxiv.org/abs/1906.02470v1
# 82  http://arxiv.org/abs/1906.01797v1
# 83  http://arxiv.org/abs/1906.01796v1
# 84  http://arxiv.org/abs/1906.02182v1
# 85  http://arxiv.org/abs/1906.01795v1
# 86  http://arxiv.org/abs/1810.05358v3
# 87  http://arxiv.org/abs/1906.01792v1
# 88  http://arxiv.org/abs/1906.01784v1
# 89  http://arxiv.org/abs/1906.02256v1
# 90  http://arxiv.org/abs/1906.01769v1
# 91  http://arxiv.org/abs/1906.01751v1
# 92  http://arxiv.org/abs/1803.07469v2
# 93  http://arxiv.org/abs/1809.06219v2
# 94  http://arxiv.org/abs/1906.01737v1
# 95  http://arxiv.org/abs/1806.06195v3
# 96  http://arxiv.org/abs/1901.02284v2
# 97  http://arxiv.org/abs/1906.02549v1
# 98  http://arxiv.org/abs/1906.02729v1
# 99  http://arxiv.org/abs/1906.01895v1
#
#                                              to.title  similarity
# 0               Learning 3D Human Dynamics from Video         0.6
# 1   Diverse Image Synthesis from Semantic Layouts ...         0.6
# 2     On Network Design Spaces for Visual Recognition         0.6
# 3      PatchFCN for Intracranial Hemorrhage Detection         0.6
# 4   Embodied Question Answering in Photorealistic ...         0.6
# 5   ShapeMask: Learning to Segment Novel Objects b...         0.6
# 6   Cost-Sensitive Active Learning for Intracrania...         0.6
# 7   Which Tasks Should Be Learned Together in Mult...         0.6
# 8   Cognitive Mapping and Planning for Visual Navi...         0.6
# 9        Habitat: A Platform for Embodied AI Research         0.6
# 10            Visual Memory for Robust Path Following         0.6
# 11  Learning Independent Object Motion from Unlabe...         0.6
# 12            SlowFast Networks for Video Recognition         0.6
# 13  Mid-Level Visual Representations Improve Gener...         0.6
# 14           Multi-Target Embodied Question Answering         0.6
# 15                Scaling Autoregressive Video Models         0.4
# 16          Color Constancy Convolutional Autoencoder         0.4
# 17  Example-Guided Style Consistent Image Synthesi...         0.4
# 18  End-to-End Learning of Geometric Deformations ...         0.4
# 19   KarNet: An Efficient Boolean Function Simplifier         0.4
# 20  Exploiting Offset-guided Network for Pose Esti...         0.4
# 21  Towards better Validity: Dispersion based Clus...         0.4
# 22  The Robust Manifold Defense: Adversarial Train...         0.4
# 23  3D Appearance Super-Resolution with Deep Learning         0.4
# 24         Does Object Recognition Work for Everyone?         0.4
# 25  State-aware Re-identification Feature for Mult...         0.4
# 26         Contextual Relabelling of Detected Objects         0.4
# 27                 Face Parsing with RoI Tanh-Warping         0.4
# 28  Removing Rain in Videos: A Large-scale Databas...         0.4
# 29            Stochastic Dynamics for Video Infilling         0.4
# ..                                                ...         ...
# 70  Farm land weed detection with region-based dee...         0.4
# 71  COCO_TS Dataset: Pixel-level Annotations Based...         0.4
# 72                   Multilinear Compressive Learning         0.4
# 73  Anytime Lane-Level Intersection Estimation Bas...         0.4
# 74  Content Adaptive Optimization for Neural Image...         0.4
# 75                    Invariant Tensor Feature Coding         0.4
# 76         Improved Inference via Deep Input Transfer         0.4
# 77  Compact Approximation for Polynomial of Covari...         0.4
# 78  A Feature Transfer Enabled Multi-Task Deep Lea...         0.4
# 79  Infant Contact-less Non-Nutritive Sucking Patt...         0.4
# 80  Progressive NAPSAC: sampling from gradually gr...         0.4
# 81  StyleNAS: An Empirical Study of Neural Archite...         0.4
# 82  StarNet: Pedestrian Trajectory Prediction usin...         0.4
# 83  One-pass Multi-task Networks with Cross-task G...         0.4
# 84  Two-Stream Region Convolutional 3D Network for...         0.4
# 85  Fully Automated Pancreas Segmentation with Two...         0.4
# 86  Efficient architecture for deep neural network...         0.4
# 87  PAC-GAN: An Effective Pose Augmentation Scheme...         0.4
# 88  Learning to Compose and Reason with Language T...         0.4
# 89  Butterfly Transform: An Efficient FFT Based Ne...         0.4
# 90  PI-Net: A Deep Learning Approach to Extract To...         0.4
# 91     An Introduction to Deep Morphological Networks         0.4
# 92             MAGSAC: marginalizing sample consensus         0.4
# 93  Ensemble learning with 3D convolutional neural...         0.4
# 94    Geo-Aware Networks for Fine Grained Recognition         0.4
# 95  Show, Attend and Translate: Unsupervised Image...         0.4
# 96        Unpaired Pose Guided Human Image Generation         0.4
# 97  Weakly-Supervised Spatio-Temporally Grounding ...         0.4
# 98  3D-RelNet: Joint Object and Relational Network...         0.4
# 99  AI-Skin : Skin Disease Recognition based on Se...         0.4
#
# [100 rows x 5 columns]

# %%
compared_to = [
    'http://arxiv.org/abs/1906.01792v1',
    'http://arxiv.org/abs/1906.02698v1',
    'http://arxiv.org/abs/1812.01601v3',
    'http://arxiv.org/abs/1906.02739v1',
]

query = """
MATCH (pub:Publication)-[]-(rel),
      (from:Publication),
      (to:Publication)
WHERE from.id = {pub} AND to.id IN {to}

WITH {item: id(pub), categories: collect(id(rel))} as pubData, [id(from)] as sourceIds, [id(to)] as targetIds
WITH collect(pubData) as data, sourceIds, targetIds

CALL algo.similarity.overlap.stream(data, {sourceIds: sourceIds, targetIds: targetIds, concurrency:1, similarityCutoff: 0.1})
YIELD item1, item2, similarity
WITH algo.getNodeById(item1) AS from, algo.getNodeById(item2) AS to, similarity

RETURN from.id, from.title, to.id, to.title, similarity
ORDER BY similarity DESC
LIMIT 100
"""

to_df(graph.run(query, pub=pub, to=compared_to))
# Out:
#                              from.id  from.title  \
# 0  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 1  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
# 2  http://arxiv.org/abs/1906.02739v1  Mesh R-CNN
#
#                                to.id  \
# 0  http://arxiv.org/abs/1812.01601v3
# 1  http://arxiv.org/abs/1906.01792v1
# 2  http://arxiv.org/abs/1906.02698v1
#
#                                             to.title  similarity
# 0              Learning 3D Human Dynamics from Video         0.6
# 1  PAC-GAN: An Effective Pose Augmentation Scheme...         0.4
# 2  Training large-scale ANNs on simulated resisti...         0.0
